# %% [markdown]
# # Misleading use of facial recognition technology by NYPD

# %% [markdown]
# Click on the link to read the article from MIT Tech Review

# %% [markdown]
# https://www.technologyreview.com/2021/04/09/1022240/clearview-ai-nypd-emails/

# %% [markdown]
# As with any technology, there are potential drawbacks to using facial recognition, such as threats to privacy, violations of rights and personal freedoms, potential data theft and other crimes. There's also the risk of errors due to flaws in the technology.

# %% [markdown]
# I used "Computer Vision Explorer" to generate an image giving the input of "Two people on a couch". It looks like the image provided by the model is not recognizable at all. If I wouldn't have known the given input, I was not able to recognize what the picture was representing.

# %%
from IPython.display import display, Image
display(Image(filename='canvas.png'))
